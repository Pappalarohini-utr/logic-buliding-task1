# %% [markdown]
# <a href="https://colab.research.google.com/github/Pappalarohini-utr/logic-buliding-task1/blob/main/Task4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Function to validate recharge
def validate_recharge(amount):
    valid_plans = [199, 299, 399, 599]

    if amount >= 50 and amount in valid_plans:
        return True
    else:
        return False


# Main Program
while True:
    amount = int(input("Enter recharge amount: "))

    if validate_recharge(amount):
        print("Recharge Successful ✅")
        break
    else:
        print("Invalid Recharge. Try Again.\n")
# Out:
# Enter recharge amount: 199
# Recharge Successful ✅

# %%
 # Function to check inventory stock
def check_inventory(products):
    for product, stock in products.items():
        if stock < 15:
            print(f"⚠️ Reorder Alert: {product} stock is low ({stock} items left)")
        else:
            print(f"✅ Stock OK: {product} has sufficient stock ({stock} items)")


# Dictionary of products and their stock quantities
inventory = {
    "Rice": 10,
    "Sugar": 25,
    "Oil": 12,
    "Soap": 30,
    "Milk Powder": 8
}

# Function call
check_inventory(inventory)
# Out:
# ⚠️ Reorder Alert: Rice stock is low (10 items left)
# ✅ Stock OK: Sugar has sufficient stock (25 items)
# ⚠️ Reorder Alert: Oil stock is low (12 items left)
# ✅ Stock OK: Soap has sufficient stock (30 items)
# ⚠️ Reorder Alert: Milk Powder stock is low (8 items left)

# %%
 # Function to process student result
def process_result(marks):
    total = 0

    # Loop to calculate total marks
    for mark in marks:
        total += mark

    average = total / len(marks)

    # Determine result
    if average >= 50:
        result = "Pass"
    else:
        result = "Fail"

    return average, result


# Example list of marks
student_marks = [60, 45, 70, 55, 40]

# Function call
avg, status = process_result(student_marks)

print("Average Marks:", avg)
print("Result:", status)
# Out:
# Average Marks: 54.0
# Result: Pass

# %%
 # Function to calculate cab fare
def calculate_fare(distance, peak):
    base_fare = 50
    per_km_rate = 12

    total_fare = base_fare + (distance * per_km_rate)

    # Apply peak hour charges
    if peak.lower() == "yes":
        total_fare += total_fare * 0.25   # 25% extra

    return total_fare


# Main Program with retry option
while True:
    try:
        distance = float(input("Enter distance in km: "))
        peak_hour = input("Is it peak hour? (yes/no): ")

        fare = calculate_fare(distance, peak_hour)
        print(f"🚖 Total Cab Fare: ₹{fare:.2f}")

        retry = input("Do you want to calculate again? (yes/no): ")
        if retry.lower() != "yes":
            print("Thank you for using Cab Fare Estimator!")
            break

    except ValueError:
        print("❌ Please enter valid numeric distance.\n")
# Out:
# Enter distance in km: 10
# Is it peak hour? (yes/no): yes
# 🚖 Total Cab Fare: ₹212.50
# Do you want to calculate again? (yes/no): no
# Thank you for using Cab Fare Estimator!

# %%
 # Function to check attendance eligibility
def check_attendance(attendance_list):
    present_count = 0

    # Loop to count present days
    for day in attendance_list:
        if day.upper() == "P":
            present_count += 1

    total_days = len(attendance_list)
    percentage = (present_count / total_days) * 100

    # Determine eligibility
    if percentage >= 75:
        status = "Eligible"
    else:
        status = "Not Eligible"

    return percentage, status


# Example attendance list
attendance = ["P", "P", "A", "P", "A", "P", "P", "P"]

# Function call
percent, result = check_attendance(attendance)

print(f"Attendance Percentage: {percent:.2f}%")
print("Eligibility Status:", result)
# Out:
# Attendance Percentage: 75.00%
# Eligibility Status: Eligible

# %%
# Function to check password strength
def check_password(password):
    has_digit = False
    has_special = False

    # Check minimum length
    if len(password) < 8:
        return "Weak Password (Minimum 8 characters required)"

    # Loop through each character
    for char in password:
        if char.isdigit():
            has_digit = True
        if char in "@#$":
            has_special = True

    # Check conditions
    if has_digit and has_special:
        return "Strong Password ✅"
    else:
        return "Weak Password (Must contain at least one digit and one special character @#$)"


# Example usage
user_password = input("Enter your password: ")
result = check_password(user_password)

print("Password Strength:", result)
# Out:
# Enter your password: 123456
# Password Strength: Weak Password (Minimum 8 characters required)
